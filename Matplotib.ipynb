# %%
import numpy as np 
import matplotlib.pyplot as plt  

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 3 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
import numpy as np 
   
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
#np.histogram(a,bins = [0,20,40,60,80,100]) 
hist,bins = np.histogram(a,bins = [0,20,40,60,80,100]) 
print (hist)
print (bins)
# Out:
# [3 4 5 2 1]
# [  0  20  40  60  80 100]

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a, bins = [0,20,40,60,80,100]) 
plt.title("histogram") 
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 3, 3, 7])
plt.ylabel('some numbers')
plt.show()

# %%
import numpy as np 
from matplotlib import pyplot as plt 

x = np.linspace(1,11) 
y = 2 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y,'o',mfc='none')
#plt.scatter(x,y,facecolors='none', hcolor='r')
plt.show()

# %%
import numpy as np 
from matplotlib import pyplot as plt
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
hist,bins = np.histogram(a,bins = [0,20,40,60,80,100]) 

hist = list(hist)
print (hist)
print (bins)

labels = ['0-20' , '20-40' , '40-60' , '60-80' , '80-100']
sizes = [(3/15)*100, (4/15)*100, (5/15)*100 , (2/15)*100 , (1/15)*100]
colors = ['green','yellow','red','blue','black']
patches, texts = plt.pie(sizes, colors=colors)
plt.legend(patches, labels)
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# [3, 4, 5, 2, 1]
# [  0  20  40  60  80 100]

# %%
labels = ['0-20' , '20-40' , '40-60' , '60-80' , '80-100']
sizes = [3,4,5,2,1]
index = np.arange(len(labels))
plt.bar(index, sizes)
plt.xlabel('ranges', fontsize=15)
plt.ylabel('frequency', fontsize=15)
plt.xticks(index, labels, fontsize=15, rotation=0)
plt.show()

# %%
import pandas as pd
table = pd.read_csv('C:\\Users\\suresh\\Desktop\\pepsi.csv')
print(table)
comp = []
frq = []
for i in range(5):
    comp.append(table['COMPANY'][i])
    frq.append(table['FREQUENCY'][i])
print(comp)
print(frq)


import numpy as np    
from matplotlib import pyplot as plt
index = np.arange(len(comp))
plt.bar(index, frq)
plt.xlabel('company name', fontsize=15)
plt.ylabel('frequency', fontsize=15)
plt.xticks(index, comp , fontsize=15, rotation=90)
plt.show()


sizes = [(19/50)*100, (8/50)*100, (5/50)*100 , (13/50)*100 , (5/50)*100]
colors = ['green','yellow','red','blue','black']
patches, texts = plt.pie(sizes, colors=colors)
plt.legend(patches, comp)
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
#      COMPANY  FREQUENCY
# 0  Coca-Cola         19
# 1  Diet Coke          8
# 2  Dr.Pepper          5
# 3      Pepsi         13
# 4     Sprite          5
# ['Coca-Cola', 'Diet Coke', 'Dr.Pepper', 'Pepsi', 'Sprite']
# [19, 8, 5, 13, 5]
